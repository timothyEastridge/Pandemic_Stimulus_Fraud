# %% [markdown]
# ## Imports

# %%
# Setup
import pandas as pd
import neo4j
import sqldf
from graphdatascience import GraphDataScience
from datetime import datetime 

# Viz
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

# Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# ## Setup

# %%
host = "bolt://localhost:7687"
user = "neo4j"
password= "letmein"

gds = GraphDataScience(host, auth=(user, password))

print(gds.version())
# Out:
# 2.1.11

# %% [markdown]
# ## Load PPP Data
# #### Data from https://www.kaggle.com/datasets/timothyeastridge/paycheck-protection-program

# %%
import os
os.chdir("C:\\Users\\TimEa\\OneDrive\\Python\\Scripts\\PPP")
os.listdir(os.curdir)  #files and directories
# Out:
# ['.ipynb_checkpoints',
#  'pandemic_response_fraud_Neo4j.ipynb',
#  'PPP.ipynb',
#  'PPP_Dataset.csv',
#  'PPP_Dataset_10k_records.csv']

# %%
df = pd.read_csv("PPP_Dataset_10k_records.csv")
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 HIGHWAY 15 SOUTH            SUMTER
# 1     PLEASANT PLACES, INC.    7684 SOUTHRAIL ROAD  NORTH CHARLESTON
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                UNKNOWN           UNKNOWN
#
#   BorrowerState BorrowerZip LoanStatusDate  ... OriginatingLenderCity  \
# 0       UNKNOWN  29150-9662     12/18/2020  ...              COLUMBUS
# 1       UNKNOWN  29420-9000     09/28/2021  ...              COLUMBUS
# 2       UNKNOWN  98112-2922     03/17/2021  ...             CHARLOTTE
# 3       UNKNOWN  92407-1740     10/16/2021  ...             CHARLOTTE
# 4       UNKNOWN         NaN     08/17/2021  ...              COLUMBUS
#
#    OriginatingLenderState      Gender      Veteran  NonProfit  \
# 0                      GA  Unanswered   Unanswered        NaN
# 1                      GA  Male Owned  Non-Veteran        NaN
# 2                      NC  Unanswered   Unanswered          Y
# 3                      NC  Male Owned  Non-Veteran        NaN
# 4                      OH  Unanswered   Unanswered        NaN
#
#    ForgivenessAmount ForgivenessDate                    file_name  \
# 0          773553.37      11/20/2020  public_150k_plus_220703.csv
# 1          746336.24      08/12/2021  public_150k_plus_220703.csv
# 2          696677.49      02/10/2021  public_150k_plus_220703.csv
# 3          395264.11      09/10/2021  public_150k_plus_220703.csv
# 4          370819.35      04/08/2021  public_150k_plus_220703.csv
#
#   Loan_Outstanding_Am Outstanding_50K
# 0            -4194.59               0
# 1            -9408.45               0
# 2            -5322.49               0
# 3           104606.89               1
# 4            -3382.35               0
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Explore Data

# %%
# Column Names
list(df.columns)
# Out:
# ['LoanNumber',
#  'DateApproved',
#  'SBAOfficeCode',
#  'ProcessingMethod',
#  'BorrowerName',
#  'BorrowerAddress',
#  'BorrowerCity',
#  'BorrowerState',
#  'BorrowerZip',
#  'LoanStatusDate',
#  'LoanStatus',
#  'Term',
#  'SBAGuarantyPercentage',
#  'InitialApprovalAmount',
#  'CurrentApprovalAmount',
#  'UndisbursedAmount',
#  'FranchiseName',
#  'ServicingLenderLocationID',
#  'ServicingLenderName',
#  'ServicingLenderAddress',
#  'ServicingLenderCity',
#  'ServicingLenderState',
#  'ServicingLenderZip',
#  'RuralUrbanIndicator',
#  'HubzoneIndicator',
#  'LMIIndicator',
#  'BusinessAgeDescription',
#  'ProjectCity',
#  'ProjectCountyName',
#  'ProjectState',
#  'ProjectZip',
#  'CD',
#  'JobsReported',
#  'NAICSCode',
#  'Race',
#  'Ethnicity',
#  'UTILITIES_PROCEED',
#  'PAYROLL_PROCEED',
#  'MORTGAGE_INTEREST_PROCEED',
#  'RENT_PROCEED',
#  'REFINANCE_EIDL_PROCEED',
#  'HEALTH_CARE_PROCEED',
#  'DEBT_INTEREST_PROCEED',
#  'BusinessType',
#  'OriginatingLenderLocationID',
#  'OriginatingLender',
#  'OriginatingLenderCity',
#  'OriginatingLenderState',
#  'Gender',
#  'Veteran',
#  'NonProfit',
#  'ForgivenessAmount',
#  'ForgivenessDate',
#  'file_name',
#  'Loan_Outstanding_Am',
#  'Outstanding_50K']

# %%
import plotly.express as px

fig = px.histogram(df, x="CurrentApprovalAmount",
                   title='Histogram of PPP Loan Amounts',
                   labels={'CurrentApprovalAmount':'Loan Approval Amount'}, # can specify one label per df column
                   opacity=0.8,
                   marginal="rug",
                   color_discrete_sequence=['indianred'] # color of histogram bars
                   )
fig.show()
# Out:
# <div>                            <div id="c9d6e880-7207-4774-ae59-9dee24715ba7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9d6e880-7207-4774-ae59-9dee24715ba7")) {                    Plotly.newPlot(                        "c9d6e880-7207-4774-ae59-9dee24715ba7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Loan Approval Amount=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indianred","opacity":0.8,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[769358.78,736927.79,691355.0,499871.0,367437.0,328840.0,289765.0,272380.0,257088.0,250000.0,174046.0,170170.0,155010.0,9538531.0,7666768.0,7398947.89,7223025.0,6528631.4,6422316.0,6412487.0,6382400.0,5928882.0,5682490.0,5157628.0,5095098.0,5036100.0,5019000.24,5015465.0,4986465.0,4808473.42,4780025.0,4290910.0,4277000.0,4029190.0,3912364.0,3793618.0,3776300.0,3774800.0,3711148.0,3554703.0,3546295.0,3535477.0,3425709.0,3403381.0,3400700.0,3388097.0,3377500.0,3344500.0,3145700.0,3142152.86,3120100.0,3079300.0,3071121.0,2987200.0,2779746.82,2769035.0,2755587.0,2751369.0,2574300.0,2489263.0,2487000.0,2464869.0,2335261.81,2269089.0,2266607.92,2264130.0,2262000.0,2235797.0,2234000.0,2227299.54,2226432.0,2210033.0,2191500.0,2191500.0,2176746.92,2161000.0,2093019.0,2063313.95,2019000.0,2009300.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,2000000.0,1999987.0,1991700.0,1991700.0,1991300.0,1991300.0,1985172.0,1981787.0,1979310.0,1975337.0,1975142.29,1973687.0,1972400.0,1956200.0,1950000.0,1934210.0,1920138.25,1914800.0,1908224.0,1890719.0,1890107.0,1883281.94,1863017.0,1854173.13,1850000.0,1845564.0,1825100.0,1818671.1,1818428.0,1814674.67,1813281.0,1800000.0,1789910.0,1788254.72,1778068.0,1772647.0,1763652.0,1761147.16,1757700.0,1745589.37,1743400.0,1740187.0,1735574.0,1710615.0,1710600.0,1710600.0,1700000.0,1669367.0,1652572.0,1647198.03,1643548.82,1641500.0,1638110.0,1615306.75,1609047.52,1603800.0,1600225.0,1600000.0,1599470.4,1594802.12,1588030.42,1576525.0,1575222.75,1575000.0,1573685.0,1522000.0,1481939.0,1479912.0,1464920.0,1461600.0,1449422.27,1434433.0,1428125.0,1425950.0,1420687.0,1419170.42,1419170.0,1416300.0,1416283.0,1414936.0,1410320.0,1410319.0,1408800.0,1408700.0,1407424.0,1396885.0,1396885.0,1376498.58,1371882.0,1371880.0,1371000.0,1371000.0,1370315.0,1360845.0,1356272.0,1342978.0,1341797.5,1340160.0,1339532.0,1328227.0,1327784.0,1316162.0,1314722.5,1314722.5,1313944.97,1310060.0,1310000.0,1306462.37,1300428.85,1297700.0,1285422.0,1284635.0,1280000.0,1269730.0,1260757.96,1256700.0,1254510.12,1254510.0,1251700.0,1245782.72,1236450.62,1235831.8,1233755.0,1232915.0,1226862.0,1207058.0,1207000.0,1204536.3,1201012.0,1198862.0,1189664.07,1177057.0,1177057.0,1176075.59,1171475.67,1154520.2,1147409.0,1146500.0,1146225.0,1144893.57,1139524.0,1131100.0,1129910.0,1125000.0,1118517.05,1115282.0,1107000.0,1097002.0,1090759.81,1086352.0,1084678.37,1079765.22,1078579.62,1072900.0,1072714.0,1071225.0,1069289.4,1064305.0,1063981.62,1062015.0,1056900.0,1050371.7,1050371.7,1048122.2,1047820.52,1047500.0,1046000.0,1036250.0,1035634.0,1035239.65,1034659.05,1032635.0,1027100.0,1026382.02,1023727.2,1021200.0,1018592.0,1013202.0,1013201.95,1012382.34,1011065.0,1009063.27,1006617.5,1005900.0,1005600.0,1002351.65,1000000.0,998702.0,997894.27,997500.0,993750.0,988447.6,987300.0,984529.0,983213.26,981965.0,980717.92,978052.0,977578.95,977577.0,977024.02,975933.7,975933.7,972646.3,968477.0,967991.85,966905.0,965009.0,961962.29,961498.15,961497.0,959270.37,958880.0,957012.0,954300.0,953753.63,946858.95,942263.0,939605.0,935737.0,935059.0,933651.0,930660.0,930660.0,927705 ...

# %% [markdown]
# # Create Unique Loan and Loan Amount Nodes

# %%
loan_nodes = sqldf.run("""
SELECT LoanNumber, sum(CurrentApprovalAmount) as LoanAmount
FROM df
GROUP BY LoanNumber
""")
loan_nodes.head()
# Out:
#    LoanNumber  LoanAmount
# 0  1000627106    497000.0
# 1  1001567103    746200.0
# 2  1002397200    232655.1
# 3  1005178402    196565.0
# 4  1005927101    224082.5

# %% [markdown]
# ### Create Constraint

# %%
c = '''
// Create constraints
CREATE CONSTRAINT loan IF NOT EXISTS ON (l:LoanNumber) ASSERT l.LoanNumber IS UNIQUE;
'''

gds.run_cypher(c)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Import LoanNumber Nodes

# %%
os.chdir("C:\\Users\\TimEa\\AppData\\Local\\Neo4j\\Relate\\Data\\dbmss\\dbms-06964896-0767-4d83-86ea-3c0db0c181e0\\import")
loan_nodes.to_csv("loan_nodes.csv",index=False)

# %%
start_time = datetime.now() 
c = '''
USING PERIODIC COMMIT 10000
LOAD CSV WITH HEADERS FROM "file:///loan_nodes.csv" AS row
MERGE (n:LoanNumber {LoanNumber: toInteger(row.LoanNumber)
, LoanAmount: toInteger(row.LoanAmount)
})
RETURN COUNT(*);
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0     10000

# %%
# Elapsed Time
time_elapsed = datetime.now() - start_time 

print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))
# Out:
# Time elapsed (hh:mm:ss.ms) 0:00:00.949871

# %% [markdown]
# # Create Unique Entity Nodes

# %%
entity_nodes = sqldf.run("""
SELECT BorrowerName,BorrowerAddress,BorrowerCity,BorrowerState
, sum(CurrentApprovalAmount) as LoanAmount
, max(BusinessAgeDescription) as BusinessAgeDescription
, max(Outstanding_50K) as Outstanding_50K
, count(*) as Entity_Loan_Count
FROM df
GROUP BY 1,2,3,4
""")
entity_nodes.head()
# Out:
#                        BorrowerName          BorrowerAddress BorrowerCity  \
# 0                              None          104 MAIN STREET   DILLINGHAM
# 1  *PARKER BUILDING MAINTENANCE INC   1233 LIBERTY PARK LOOP     VESTAVIA
# 2                      1 SOURCE LLC          3240 MOFFETT RD       MOBILE
# 3                      10 BELOW LLC  2500 CRESTWOOD BLVD 500     IRONDALE
# 4           2215 NORTHPORT OPCO LLC         2215 32ND STREET    NORTHPORT
#
#   BorrowerState  LoanAmount             BusinessAgeDescription  \
# 0            AK   156767.42  Existing or more than 2 years old
# 1            AL   235000.00  Existing or more than 2 years old
# 2            AL   218940.00  Existing or more than 2 years old
# 3            AL  1393000.00  Existing or more than 2 years old
# 4            AL  1358800.00    New Business or 2 years or less
#
#    Outstanding_50K  Entity_Loan_Count
# 0                0                  1
# 1                0                  1
# 2                0                  1
# 3                0                  1
# 4                1                  1

# %% [markdown]
# ### Create Indexes

# %%
c = '''
CREATE INDEX ON :Entity(BorrowerName)'''
gds.run_cypher(c)
c = '''
CREATE INDEX ON :Entity(BorrowerAddress)'''
gds.run_cypher(c)
c = '''
CREATE INDEX ON :Entity(BorrowerCity)'''
gds.run_cypher(c)
c = '''
CREATE INDEX ON :Entity(BorrowerState)'''
gds.run_cypher(c)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Import Entity Nodes

# %%
os.chdir("C:\\Users\\TimEa\\AppData\\Local\\Neo4j\\Relate\\Data\\dbmss\\dbms-06964896-0767-4d83-86ea-3c0db0c181e0\\import")
entity_nodes.to_csv("entity_nodes.csv",index=False)

# %%
c = '''
USING PERIODIC COMMIT 10000
LOAD CSV WITH HEADERS FROM "file:///entity_nodes.csv" AS row
MERGE (n:Entity {BorrowerName: COALESCE(row.BorrowerName,"")
, BorrowerAddress: row.BorrowerAddress
, BorrowerCity: row.BorrowerCity
, BorrowerState: row.BorrowerState
})
RETURN COUNT(*);
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      9671

# %% [markdown]
# # Create Edges / Relationships

# %%
edges_borrower_to_loan = sqldf.run("""
SELECT LoanNumber,BorrowerName,BorrowerAddress,BorrowerCity,BorrowerState
FROM df
""")
edges_borrower_to_loan.head()
# Out:
#    LoanNumber              BorrowerName        BorrowerAddress  \
# 0  9547507704     SUMTER COATINGS, INC.  2410 HIGHWAY 15 SOUTH
# 1  9777677704     PLEASANT PLACES, INC.    7684 SOUTHRAIL ROAD
# 2  5791407702   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E
# 3  6223567700  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD
# 4  9662437702              AERO BOX LLC                UNKNOWN
#
#        BorrowerCity BorrowerState
# 0            SUMTER       UNKNOWN
# 1  NORTH CHARLESTON       UNKNOWN
# 2           SEATTLE       UNKNOWN
# 3    SAN BERNARDINO       UNKNOWN
# 4           UNKNOWN       UNKNOWN

# %% [markdown]
# ### Import Relationships

# %%
os.chdir("C:\\Users\\TimEa\\AppData\\Local\\Neo4j\\Relate\\Data\\dbmss\\dbms-06964896-0767-4d83-86ea-3c0db0c181e0\\import")
edges_borrower_to_loan.to_csv("edges_borrower_to_loan.csv",index=False)

# %%
c = '''
USING PERIODIC COMMIT 10000
LOAD CSV WITH HEADERS FROM "file:///edges_borrower_to_loan.csv" AS row
MATCH (source:Entity {BorrowerName: COALESCE(row.BorrowerName,""), BorrowerAddress: row.BorrowerAddress, BorrowerCity: row.BorrowerCity, BorrowerState: row.BorrowerState})
MATCH (target:LoanNumber {LoanNumber: toInteger(row.LoanNumber)})
MERGE (source)-[:RECEIVED_LOAN]->(target)
RETURN COUNT(*);
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0     10000

# %% [markdown]
# ### Connect Entities with Shared Address

# %%
c = '''
MATCH (a:Entity),(b:Entity)
WHERE a.BorrowerAddress = b.BorrowerAddress
    AND a.BorrowerCity = b.BorrowerCity
    AND a.BorrowerState = b.BorrowerState
    AND id(a) < id(b)
CREATE (a)-[:SHARES_ADDRESS]->(b) 
RETURN COUNT(*);
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      1215

# %% [markdown]
# ### Connect Entities with Shared Address

# %%
c = '''
MATCH (a:Entity),(b:Entity)
WHERE a.BorrowerAddress = b.BorrowerAddress
    AND a.BorrowerCity = b.BorrowerCity
    AND a.BorrowerState = b.BorrowerState
    AND id(a) < id(b)
CREATE (a)-[:SHARES_ADDRESS]->(b) 
RETURN COUNT(*);
'''

gds.run_cypher(c)
# Out:
#    COUNT(*)
# 0      1215

# %% [markdown]
# ### Which Entities Received the Highest Number of Loans?

# %%
c = '''
MATCH (a:Entity)-[r1:RECEIVED_LOAN]->(b:LoanNumber)
RETURN a.BorrowerName as BorrowerName, sum(b.LoanAmount) as LoanAmount, count(r1) as LoanCount
ORDER BY LoanCount * log(LoanAmount) DESC
LIMIT 10
'''

gds.run_cypher(c)
# Out:
#                         BorrowerName  LoanAmount  LoanCount
# 0  YOUNG MEN'S CHRISTIAN ASSOCIATION     4038132          3
# 1     ASBURY UNITED METHODIST CHURCH     1345409          3
# 2      FIRST UNITED METHODIST CHURCH      905222          3
# 3     ACTION ENTERPRISE HOLDINGS LLC    12000000          2
# 4         PCH HOTELS AND RESORTS INC    11501800          2
# 5        BIRMINGHAM-SOUTHERN COLLEGE     6407500          2
# 6                 ADTRAV CORPORATION     6023032          2
# 7                        VULCAN INC.     5834600          2
# 8                  RUSSO CORPORATION     5705981          2
# 9        THE MCPHERSON COMPANIES INC     5406100          2

# %% [markdown]
# ### View Info for Loan Recipient

# %%
c = '''
MATCH (a:Entity)
WHERE a.BorrowerName = 'ASBURY UNITED METHODIST CHURCH'
RETURN a.BorrowerName, a.BorrowerAddress, a.BorrowerCity, a.BorrowerState
LIMIT 10
'''

gds.run_cypher(c)
# Out:
#                    a.BorrowerName      a.BorrowerAddress a.BorrowerCity  \
# 0  ASBURY UNITED METHODIST CHURCH  6690 CAHABA VALLEY RD     BIRMINGHAM
# 1  ASBURY UNITED METHODIST CHURCH          980 HUGHES RD        MADISON
#
#   a.BorrowerState
# 0              AL
# 1              AL
